# %%
import os
import tensorflow as tf
# Out:
# 2023-11-16 13:18:29.944286: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-16 13:18:29.977392: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-16 13:18:29.978188: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-16 13:18:30.821033: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# !ls saved_models
# Out:
# 1693815807  1693820581

# %%
MODEL_NAME = '1693815807'

# %%
converter = tf.lite.TFLiteConverter.from_saved_model(f'./saved_models/{MODEL_NAME}')
tflite_model = converter.convert()
# Out:
# 2023-09-04 11:38:02.903364: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# 2023-09-04 11:38:02.903404: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# 2023-09-04 11:38:02.904017: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: ./saved_models/1693815807
# 2023-09-04 11:38:02.932466: I tensorflow/cc/saved_model/reader.cc:91] Reading meta graph with tags { serve }
# 2023-09-04 11:38:02.932503: I tensorflow/cc/saved_model/reader.cc:132] Reading SavedModel debug info (if present) from: ./saved_models/1693815807
# 2023-09-04 11:38:02.935783: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-09-04 11:38:02.937463: I tensorflow/cc/saved_model/loader.cc:231] Restoring SavedModel bundle.
# 2023-09-04 11:38:02.992390: I tensorflow/cc/saved_model/loader.cc:215] Running initialization op on SavedModel bundle at path: ./saved_models/1693815807
# 2023-09-04 11:38:03.005970: I tensorflow/cc/saved_model/loader.cc:314] SavedModel load for tags { serve }; Status: success: OK. Took 101958 microseconds.
# 2023-09-04 11:38:03.019365: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.

# %%
tflite_models_dir = './tflite_models'
if not os.path.exists(tflite_models_dir):
    os.makedirs(tflite_models_dir)

# %%
tflite_model_name = os.path.join(tflite_models_dir, f'{MODEL_NAME}.tflite')
tflite_model_name
# Out:
# './tflite_models/1693815807.tflite'

# %%
with open(tflite_model_name, 'wb') as fp:
    fp.write(tflite_model)

# %%
# !ls tflite_models
# Out:
# 1693815807.tflite

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=6f1fd91f-a434-4542-983d-3ce5ae14ac33' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
