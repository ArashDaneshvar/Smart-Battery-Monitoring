# %% [markdown]
# # HW2: Data preparation

# %% [markdown]
# Following a recent update to the Deepnote platform, there have been issues with read/write file operations. To resolve this problem, please take the following steps:
# 1. Ensure that you have uploaded both `yn-train.zip` and `yn-test.zip` to your Deepnote project space. Double-check the `Files` tab on the left panel to confirm their presence.
# 1. Open the `Init` notebook located on the left sidebar.
# 1. Add a new code cell at the bottom of the notebook.
# 1. Insert the following lines into the newly created code cell:
# ```
# !cp /work/yn-train.zip /tmp/yn-train.zip
# !cp /work/yn-test.zip /tmp/yn-test.zip
# !unzip -oqqq /work/yn-train.zip -d /tmp/yn-train
# !unzip -oqqq /work/yn-test.zip -d /tmp/yn-test
# ```
#
# Additionally, update the dataset locations in the TensorFlow code to read data from `/tmp/yn-train/*` and `/tmp/yn-test/*.`

# %%
import tensorflow as tf
# Out:
# 2023-12-04 12:12:34.577897: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-12-04 12:12:34.579622: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-04 12:12:34.617472: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-04 12:12:34.618565: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
yes_no_train_ds = tf.data.Dataset.list_files('/tmp/yn-train/*')
yes_no_test_ds = tf.data.Dataset.list_files('/tmp/yn-test/*')

# %%
num_train_files = len(yes_no_train_ds)
num_test_files = len(yes_no_test_ds)

print('Training set size:', num_train_files)
print('Test set size:', num_test_files)
# Out:
# Training set size: 1600
# Test set size: 200

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=6f1fd91f-a434-4542-983d-3ce5ae14ac33' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
