# %%
import tensorflow as tf
from visualization import visualize_features
# Out:
# 2023-10-13 13:30:47.685609: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-10-13 13:30:47.687648: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-10-13 13:30:47.733027: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-10-13 13:30:47.733501: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
visualize_features('examples/go_0a9f9af7_nohash_1.wav', tf.int16, 16000, 0.04, 0.02, 40, 20, 4000, 10)
# Out:
# 2023-10-13 13:30:49.834336: I tensorflow_io/core/kernels/cpu_check.cc:128] Your CPU supports instructions that this TensorFlow IO binary was not compiled to use: AVX AVX2 AVX512F FMA
# 2023-10-13 13:30:49.836171: W tensorflow_io/core/kernels/audio_video_mp3_kernels.cc:271] libmp3lame.so.0 or lame functions are not available

# %%
visualize_features('examples/go_0ab3b47d_nohash_0.wav', tf.int16, 16000, 0.04, 0.02, 40, 20, 4000, 10)

# %%
visualize_features('examples/stop_0b40aa8e_nohash_0.wav', tf.int16, 16000, 0.04, 0.02, 40, 20, 4000, 10)

# %%
visualize_features('examples/stop_0b56bcfe_nohash_1.wav', tf.int16, 16000, 0.04, 0.02, 40, 20, 4000, 10)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=6f1fd91f-a434-4542-983d-3ce5ae14ac33' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
