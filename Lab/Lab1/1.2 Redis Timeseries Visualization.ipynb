# %%
import redis

REDIS_HOST = 'redis-11874.c250.eu-central-1-1.ec2.cloud.redislabs.com'
REDIS_PORT = 11874
REDIS_USERNAME = 'default'
REDIS_PASSWORD = 'AtIkh24XIrE7X77rEQfbzvyvLaMDfp01'


redis_client = redis.Redis(host=REDIS_HOST, port=REDIS_PORT, username=REDIS_USERNAME, password=REDIS_PASSWORD)
is_connected = redis_client.ping()
print('Redis Connected:', is_connected)
# Out:
# Redis Connected: True

# %%
from_str = '2023-10-11 18:15:00'

# %%
to_str = '2023-10-11 18:45:00'

# %%
from datetime import datetime

from_datetime = datetime.fromisoformat(from_str)
from_timestamp = from_datetime.timestamp()
from_timestamp_ms = int(from_timestamp * 1000)

to_datetime = datetime.fromisoformat(to_str)
to_timestamp = to_datetime.timestamp()
to_timestamp_ms = int(to_timestamp * 1000)
values = redis_client.ts().range('integers', from_timestamp_ms, to_timestamp_ms)

print(len(values))
# Out:
# 0

# %%
datetime.now()
# Out:
# datetime.datetime(2023, 10, 11, 16, 37, 44, 3247)

# %%
from datetime import timedelta

dt = timedelta(hours=2)

from_datetime_utc = from_datetime - dt
from_timestamp = from_datetime_utc.timestamp()
from_timestamp_ms = int(from_timestamp * 1000)

to_datetime_utc = to_datetime - dt
to_timestamp = to_datetime_utc.timestamp()
to_timestamp_ms = int(to_timestamp * 1000)

values = redis_client.ts().range('integers', from_timestamp_ms, to_timestamp_ms)

print(len(values))
# Out:
# 6

# %%
import pandas as pd

df = pd.DataFrame(values, columns=['Datetime', 'Integers'])
df
# Out:
#         Datetime  Integers
# 0  1697042173622       1.0
# 1  1697042173652       2.0
# 2  1697042257541       1.0
# 3  1697042257571       2.0
# 4  1697042258571       1.0
# 5  1697042258602       2.0

# %%
(lambda: DeepnoteChart(df, """{"data":{"name":"placeholder"},"mark":{"type":"point","tooltip":true},"height":220,"$schema":"https://vega.github.io/schema/vega-lite/v4.json","autosize":{"type":"fit"},"encoding":{"x":{"sort":null,"type":"temporal","field":"Datetime","scale":{"type":"linear","zero":false}},"y":{"sort":null,"type":"quantitative","field":"Integers","scale":{"type":"linear","zero":false}},"color":{"sort":null,"type":"nominal","field":"","scale":{"type":"linear","zero":false}}}}""") if 'DeepnoteChart' in globals() else _dntk.DeepnoteChart(df, """{"data":{"name":"placeholder"},"mark":{"type":"point","tooltip":true},"height":220,"$schema":"https://vega.github.io/schema/vega-lite/v4.json","autosize":{"type":"fit"},"encoding":{"x":{"sort":null,"type":"temporal","field":"Datetime","scale":{"type":"linear","zero":false}},"y":{"sort":null,"type":"quantitative","field":"Integers","scale":{"type":"linear","zero":false}},"color":{"sort":null,"type":"nominal","field":"","scale":{"type":"linear","zero":false}}}}"""))()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=6f1fd91f-a434-4542-983d-3ce5ae14ac33' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
